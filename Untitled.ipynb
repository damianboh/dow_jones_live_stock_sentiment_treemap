# %%
# libraries for webscraping, parsing and getting stock data
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import yfinance as yf
import time

# for plotting and data manipulation
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

# NLTK VADER for sentiment analysis
import nltk
nltk.downloader.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# for getting current date and time to print 'last updated'
from datetime import datetime

# Get All Tickers from Dow Jones Index
df_dow_jones = pd.read_html("https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average")[1]
tickers = df_dow_jones['Symbol'].tolist()

# Scrape the Date, Time and News Headlines Data
finwiz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers = { "user-Agent": 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'})

    try:
       response = urlopen(req)   
    except:
       time.sleep(10) # if there is an error and request is blocked, do it more slowly by waiting for 10 seconds before requesting again
       response = urlopen(req)  
        
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)

    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

	

# Parse the Date, Time and News Headlines into a Python List
parsed_news = []
# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element
        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
parsed_news
# Out:
# [['MMM',
#   'Sep-01-22',
#   '05:13PM',
#   '3M Should Be Blocked From Health Care Spinoff, New Suit Argues'],
#  ['MMM',
#   'Sep-01-22',
#   '04:42PM',
#   'UPDATE 3-Veterans seeking earplug damages sue to block 3M healthcare spinoff'],
#  ['MMM',
#   'Sep-01-22',
#   '04:39PM',
#   'Veterans seeking earplug damages sue to block 3M healthcare spinoff'],
#  ['MMM',
#   'Sep-01-22',
#   '02:45PM',
#   'Home Away From Home: 3M Brands Help College Students and Young Adults Prepare for Independent Living'],
#  ['MMM',
#   'Sep-01-22',
#   '10:54AM',
#   '3M Plans Job Cuts to Rein in Expenses as Legal Troubles Grow'],
#  ['MMM',
#   'Sep-01-22',
#   '09:09AM',
#   '3M Finalizes Separation of its Food Safety Business and Merger of the Business with Neogen; Accepts Shares Tendered in Exchange Offer'],
#  ['MMM',
#   'Sep-01-22',
#   '09:04AM',
#   "Is It Time to Buy the Dow Jones' 4 Worst-Performing August Stocks?"],
#  ['MMM',
#   'Sep-01-22',
#   '08:38AM',
#   '3M Plans Job Cuts to Rein in Expenses as Legal Troubles Grow'],
#  ['MMM',
#   'Sep-01-22',
#   '07:52AM',
#   '3M planning job cuts amid slowing economy, earplug case defeat'],
#  ['MMM',
#   'Sep-01-22',
#   '06:30AM',
#   '3M Announces Preliminary Results of Split-Off Exchange Offer; Intends to Accept Tendered Shares and Expects Closing of the Neogen Transaction Today'],
#  ['MMM',
#   'Aug-31-22',
#   '07:10PM',
#   '3Ms Bankruptcy Setback Deepens Earplug Litigation Troubles'],
#  ['MMM',
#   'Aug-31-22',
#   '05:45PM',
#   '3M (MMM) Stock Moves -0.41%: What You Should Know'],
#  ['MMM',
#   'Aug-31-22',
#   '01:41PM',
#   '3M: Low Valuation May Offset Litigation Risks'],
#  ['MMM',
#   'Aug-31-22',
#   '10:30AM',
#   'If You Invested $10,000 in 3M in 2017, This Is How Much You Would Have Today'],
#  ['MMM', 'Aug-31-22', '10:10AM', '3M Announces Upcoming Investor Event'],
#  ['MMM',
#   'Aug-29-22',
#   '06:33PM',
#   '3M Sets Final Exchange Ratio in Split-Off Exchange Offer in Connection with Neogen Transaction'],
#  ['MMM',
#   'Aug-29-22',
#   '12:24PM',
#   "3M's (MMM) Earplug Suits to Proceed, Averting Bankruptcy Rules"],
#  ['MMM',
#   'Aug-29-22',
#   '06:54AM',
#   'Zacks Investment Ideas feature highlights: Emerson Electric, 3M and Sysco'],
#  ['MMM',
#   'Aug-27-22',
#   '01:07PM',
#   '3M Bankruptcy Tactic Fails as Combat Earplug Suits Move to Trial'],
#  ['MMM',
#   'Aug-26-22',
#   '07:21PM',
#   '3M Statement Regarding Bankruptcy Court Decision'],
#  ['MMM',
#   'Aug-26-22',
#   '05:17PM',
#   '3M Is Denied Bankruptcy Shield Against Mass Earplug Claims'],
#  ['MMM',
#   'Aug-26-22',
#   '04:29PM',
#   '3M Cant Use\xa0Bankruptcy to Halt\xa0Lawsuits Over Combat Earplugs, Judge Rules'],
#  ['MMM',
#   'Aug-26-22',
#   '03:49PM',
#   "Court rejects 3M effort to block combat earplug lawsuits with subsidiary's bankruptcy filing"],
#  ['MMM',
#   'Aug-26-22',
#   '03:05PM',
#   'UPDATE 4-3M combat earplug lawsuits to proceed, judge rules, despite bankruptcy case'],
#  ['MMM',
#   'Aug-26-22',
#   '02:57PM',
#   '3M combat earplug lawsuits to proceed, judge rules, despite bankruptcy case'],
#  ['MMM',
#   'Aug-26-22',
#   '02:34PM',
#   '3 Dividend Kings Income Investors Will Love'],
#  ['MMM',
#   'Aug-25-22',
#   '05:41AM',
#   'My Top Beaten-Down Industrial Conglomerate Stock to Buy and Hold for the Next Decade'],
#  ['MMM',
#   'Aug-24-22',
#   '09:00AM',
#   'Here is What to Know Beyond Why 3M Company (MMM) is a Trending Stock'],
#  ['MMM',
#   'Aug-22-22',
#   '05:28PM',
#   '3M Awaits Bankruptcy Ruling That May Sink Litigation Tactic'],
#  ['MMM',
#   'Aug-20-22',
#   '10:37AM',
#   '3 Top Dividend Kings to Buy for the Long Haul'],
#  ['MMM',
#   'Aug-19-22',
#   '09:45AM',
#   "3M (MMM) Stock Declines 18% YTD: What's Pulling it Down?"],
#  ['MMM',
#   'Aug-18-22',
#   '11:03AM',
#   '3M Unit Defends Request to Shield Parent From Mass Earplug Lawsuits'],
#  ['MMM',
#   'Aug-18-22',
#   '07:34AM',
#   '1 Monster Risk for 3M That You Might Want to Avoid'],
#  ['MMM',
#   'Aug-18-22',
#   '12:10AM',
#   'Mayar Capital on 3M Company (MMM): Weve Always Liked this Business with its Diversified Revenues'],
#  ['MMM',
#   'Aug-17-22',
#   '01:30PM',
#   "Neogen Shareholders Approve All Proposals Required for Combination with 3M's Food Safety Business"],
#  ['MMM',
#   'Aug-17-22',
#   '09:00AM',
#   "3M's Hutchinson Minnesota Plant Celebrates 75 Years"],
#  ['MMM',
#   'Aug-17-22',
#   '07:30AM',
#   "What 3M Company's (NYSE:MMM) ROE Can Tell Us"],
#  ['MMM',
#   'Aug-16-22',
#   '12:28PM',
#   "3M Faces $100 Billion in Losses From Veterans' Earplug Suits, Expert Says"],
#  ['MMM',
#   'Aug-15-22',
#   '06:02PM',
#   'Judge Knocks 3M Bankruptcy Strategy for Military Earplug Lawsuits'],
#  ['MMM',
#   'Aug-15-22',
#   '05:45PM',
#   'Minnesota VFW weighs in on 3M earplug bankruptcy move'],
#  ['MMM',
#   'Aug-15-22',
#   '09:16AM',
#   '10 Famous Value Stocks that Underperformed in 2022'],
#  ['MMM',
#   'Aug-14-22',
#   '06:00AM',
#   '3 High-Yield Dividend Stocks That Are Passive Income Machines'],
#  ['MMM', 'Aug-14-22', '05:01AM', 'Better Buy: 3M or Stanley Black & Decker?'],
#  ['MMM',
#   'Aug-12-22',
#   '04:08PM',
#   "What 3M's Health Care Spin-Off Means to Investors"],
#  ['MMM', 'Aug-12-22', '11:39AM', '3M Board Declares Quarterly Dividend'],
#  ['MMM',
#   'Aug-12-22',
#   '10:45AM',
#   'This Evergreen Dividend Stock Could Soon Get Even Sweeter'],
#  ['MMM',
#   'Aug-11-22',
#   '05:57PM',
#   'Redditors are Buying These 10 Dividend ETFs in August'],
#  ['MMM',
#   'Aug-11-22',
#   '05:51PM',
#   'Judge Questions 3M Earplug Units Path to Bankruptcy'],
#  ['MMM',
#   'Aug-11-22',
#   '09:08AM',
#   'The Zacks Analyst Blog Highlights S&P Global, Sony Group, 3M, Northrop Grumman and Shopify'],
#  ['MMM',
#   'Aug-11-22',
#   '08:01AM',
#   '3M earplug plaintiffs try to block moving cases to bankruptcy court'],
#  ['MMM',
#   'Aug-11-22',
#   '07:00AM',
#   'Veterans Suing 3M Over Earplugs Oppose Shifting Cases to Bankruptcy Court'],
#  ['MMM',
#   'Aug-10-22',
#   '02:40PM',
#   'Top Analyst Reports for S&P Global, Sony & 3M'],
#  ['MMM',
#   'Aug-10-22',
#   '09:00AM',
#   'Is Trending Stock 3M Company (MMM) a Buy Now?'],
#  ['MMM', 'Aug-09-22', '10:23AM', '7 Blue-Chip Stocks That Will Survive 2022'],
#  ['MMM',
#   'Aug-09-22',
#   '07:00AM',
#   '3 Dividend Stocks to Buy to Beat Runaway Inflation'],
#  ['MMM',
#   'Aug-08-22',
#   '08:12AM',
#   '3M new health care company will need a headquarters. Can the Twin Cities hang onto it?'],
#  ['MMM',
#   'Aug-05-22',
#   '09:00AM',
#   'Golf That Matters: 3M Uses 3M Open To Give Back to the Community'],
#  ['MMM',
#   'Aug-05-22',
#   '05:38AM',
#   'The Best Defense Dividend Stocks for a Lifetime of Passive Income'],
#  ['MMM',
#   'Aug-04-22',
#   '12:41PM',
#   '3M Commences Split-Off Exchange Offer for Food Safety Business'],
#  ['MMM',
#   'Aug-04-22',
#   '09:10AM',
#   '3M upgrades make negative pressure wound therapy with instillation easier for clinicians to initiate'],
#  ['MMM',
#   'Aug-03-22',
#   '03:37PM',
#   'Why Shares of Knowles Fell More Than 17% Today'],
#  ['MMM',
#   'Aug-02-22',
#   '07:48AM',
#   '1 Green Flag for 3M in 2022, and 1 Red Flag'],
#  ['MMM',
#   'Aug-01-22',
#   '11:05AM',
#   '3M and Nordson introduce a new automated bonding system that provides a faster, simpler, more sustainable solution for manufacturing'],
#  ['MMM',
#   'Jul-31-22',
#   '08:10AM',
#   'This Dow Jones Stock Has a Huge Risk You Might Not Know About'],
#  ['MMM',
#   'Jul-31-22',
#   '06:45AM',
#   'This Is My Favorite Industrial Stock Right Now'],
#  ['MMM',
#   'Jul-30-22',
#   '07:00AM',
#   'Industrious Investing: 3 Industrials With 3% or Higher Dividend Yields'],
#  ['MMM',
#   'Jul-29-22',
#   '06:53PM',
#   '3M Is Making Big Changes. Its Still Not Time to Buy the Stock.'],
#  ['MMM',
#   'Jul-27-22',
#   '07:31PM',
#   'Judge Questions 3Ms Use of Bankruptcy to Fight Veterans Suits'],
#  ['MMM',
#   'Jul-27-22',
#   '11:07AM',
#   'News on 3M, Raytheon, Coinbase: The National Observer July 27, 2022'],
#  ['MMM',
#   'Jul-27-22',
#   '08:12AM',
#   'Will $1 billion be enough to cover 3M earplug lawsuits?'],
#  ['MMM', 'Jul-26-22', '06:00PM', 'The 7 Best Industrial Stocks to Buy Now'],
#  ['MMM',
#   'Jul-26-22',
#   '05:32PM',
#   '3Ms $1 billion fund for resolving veterans earplugs litigation not enough, says law professor'],
#  ['MMM',
#   'Jul-26-22',
#   '04:55PM',
#   'US STOCKS-Indexes drop as Walmart profit warning spooks investors'],
#  ['MMM',
#   'Jul-26-22',
#   '03:32PM',
#   "3M is spinning off its health care business. Here's what that could look like."],
#  ['MMM',
#   'Jul-26-22',
#   '03:01PM',
#   '3M Plans To Spin-Off Of Health Care Business; Subsidiary Aearo Initiates Bankruptcy Proceedings'],
#  ['MMM',
#   'Jul-26-22',
#   '02:00PM',
#   '3M: prodding a prodigal into the bankruptcy courts'],
#  ['MMM',
#   'Jul-26-22',
#   '01:28PM',
#   '3M to Spin Off Healthcare Business;  Earplugs Unit Files for Bankruptcy'],
#  ['MMM',
#   'Jul-26-22',
#   '01:19PM',
#   "3M's (MMM) Q2 Earnings & Revenues Beat Estimates, Decline Y/Y"],
#  ['MMM',
#   'Jul-26-22',
#   '12:53PM',
#   'US STOCKS-Wall Street falls as Walmart warning rattles retail sector'],
#  ['MMM',
#   'Jul-26-22',
#   '12:49PM',
#   '3Ms attempt to resolve earplug litigation woefully underfunded says lead plaintiffs counsel'],
#  ['MMM',
#   'Jul-26-22',
#   '12:10PM',
#   '3M Shares Gain As Q2 Results Exceed Street Expectation'],
#  ['MMM', 'Jul-26-22', '11:47AM', 'Why 3M Stock Popped Today'],
#  ['MMM',
#   'Jul-26-22',
#   '10:56AM',
#   'US STOCKS-Wall Street falls as Walmart warning rattles retail stocks'],
#  ['MMM',
#   'Jul-26-22',
#   '10:10AM',
#   'In a busy morning 3M announces healthcare spin off, mixed earnings and subsidiarys voluntary bankruptcy'],
#  ['MMM',
#   'Jul-26-22',
#   '09:45AM',
#   'General Electric posts blowout earnings, 3M to spin off health care unit'],
#  ['MMM',
#   'Jul-26-22',
#   '09:01AM',
#   '3M Stock Is Rising. Its Earnings Report Held a Ton of News.'],
#  ['MMM',
#   'Jul-26-22',
#   '08:57AM',
#   'US STOCKS-Wall Street set to open lower as Walmart warning rattles retail stocks'],
#  ['MMM',
#   'Jul-26-22',
#   '08:37AM',
#   '3M Stock Is Rising After Beating Earnings Expectations and Announcing a Healthcare Spin'],
#  ['MMM',
#   'Jul-26-22',
#   '08:09AM',
#   '3M Stock Surges After Q2 Earnings Beat, Healthcare Spin-Off Plans'],
#  ['MMM',
#   'Jul-26-22',
#   '08:07AM',
#   '3M to spin out health care business; earplug business filing Chapter 11'],
#  ['MMM',
#   'Jul-26-22',
#   '08:06AM',
#   '3M earplugs business seeks bankruptcy protection amid lawsuit threat'],
#  ['MMM',
#   'Jul-26-22',
#   '07:55AM',
#   '3M (MMM) Q2 Earnings and Revenues Surpass Estimates'],
#  ['MMM',
#   'Jul-26-22',
#   '07:48AM',
#   'US STOCKS-Futures fall after Walmart warning spooks retail stocks'],
#  ['MMM',
#   'Jul-26-22',
#   '07:25AM',
#   '3M Will Spin Off Its Healthcare Business. The Stock Rises.'],
#  ['MMM',
#   'Jul-26-22',
#   '06:56AM',
#   '3M stock rises after mixed earnings, announcement of healthcare spinoff'],
#  ['MMM',
#   'Jul-26-22',
#   '06:51AM',
#   'UPDATE 3-3M to spin off healthcare business into new public company'],
#  ['MMM',
#   'Jul-26-22',
#   '06:43AM',
#   '3M to spin off health care business and create two listed companies'],
#  ['MMM', 'Jul-26-22', '06:42AM', '3M to spin off healthcare business'],
#  ['MMM', 'Jul-26-22', '06:31AM', '3M Reports Second-Quarter 2022 Results'],
#  ['MMM',
#   'Jul-26-22',
#   '06:30AM',
#   '3M Subsidiary Aearo Technologies Takes Action to Efficiently and Equitably Resolve Litigation Related to Combat Arms Earplugs'],
#  ['AXP',
#   'Sep-01-22',
#   '05:36PM',
#   'SFOs American Express Centurion Lounge to close for big expansion'],
#  ['AXP',
#   'Sep-01-22',
#   '03:17PM',
#   "We're Securing This Company a Spot in the Bullpen"],
#  ['AXP',
#   'Aug-31-22',
#   '10:36AM',
#   'NYC Pensions Press Mastercard, AmEx to Track Gun Sales'],
#  ['AXP',
#   'Aug-31-22',
#   '05:06AM',
#   "86% of Warren Buffett's Portfolio Is Invested in These 10 Stocks"],
#  ['AXP',
#   'Aug-30-22',
#   '09:25AM',
#   'UPDATE 1-NYC, California pensions ask credit card firms to help track suspicious gun buys'],
#  ['AXP',
#   'Aug-30-22',
#   '07:30AM',
#   '10 Dividend Stocks to Buy According to Jim Simons Renaissance Technologies'],
#  ['AXP',
#   'Aug-30-22',
#   '07:00AM',
#   'NYC, California pension leaders seek payment codes for gun sellers'],
#  ['AXP',
#   'Aug-29-22',
#   '07:00AM',
#   'American Express Leverages A Global Presence And Enticing Credit Card Rewards'],
#  ['AXP',
#   'Aug-27-22',
#   '07:37AM',
#   '3 No-Brainer Warren Buffett Stocks to Buy Right Now'],
#  ['AXP',
#   'Aug-26-22',
#   '01:47PM',
#   '10 Best Blue Chip Dividend Stocks to Invest In'],
#  ['AXP', 'Aug-25-22', '03:05PM', 'Cross-Sector: Market Data Highlights'],
#  ['AXP',
#   'Aug-25-22',
#   '09:54AM',
#   'AmEx (AXP) Complies With RBI Data Rules: Key Market Opens'],
#  ['AXP',
#   'Aug-24-22',
#   '05:57PM',
#   'These 3 Blue-Chip Stocks Are Great Shields Against Volatility'],
#  ['AXP',
#   'Aug-24-22',
#   '09:47AM',
#   'India central bank lifts curbs on AmEx after compliance on data rules'],
#  ['AXP',
#   'Aug-24-22',
#   '09:46AM',
#   'UPDATE 3-India c.bank lifts curbs on AmEx after compliance on data rules'],
#  ['AXP',
#   'Aug-24-22',
#   '06:46AM',
#   "3 Stocks Warren Buffett Hasn't Sold a Penny of Since the Pandemic Started"],
#  ['AXP',
#   'Aug-23-22',
#   '08:08AM',
#   'How Making Short-Term Investing Decisions Right Now Can Go Against Your Long-Term Interests'],
#  ['AXP',
#   'Aug-22-22',
#   '03:23PM',
#   '7 Growth Stocks That Are Screaming Buys Right Now'],
#  ['AXP',
#   'Aug-18-22',
#   '02:32PM',
#   "AmEx's (AXP) Tie-Up to Let WebBank Issue Amex Cards Via Fintechs"],
#  ['AXP',
#   'Aug-17-22',
#   '11:45AM',
#   '3 Undervalued Bargain Stocks to Buy Before they Bounce'],
#  ['AXP',
#   'Aug-16-22',
#   '09:00AM',
#   'American Express Chief Financial Officer to Participate in Barclays Global Financial Services Conference'],
#  ['AXP',
#   'Aug-15-22',
#   '06:35PM',
#   'Stocks moving in after-hours trading: Apple, Activision Blizzard, Ally Financial and more'],
#  ['AXP',
#   'Aug-15-22',
#   '05:37PM',
#   'Warren Buffetts Berkshire Hathaway Keeps Spending Through Volatile Markets'],
#  ['AXP',
#   'Aug-15-22',
#   '12:30PM',
#   'Clear Secure, Inc. (YOU) Q2 2022 Earnings Call Transcript'],
#  ['AXP',
#   'Aug-15-22',
#   '10:23AM',
#   '3 Stocks to Buy With Inflation Potentially Peaking'],
#  ['AXP', 'Aug-14-22', '05:00AM', '3 Warren Buffett Stocks to Buy Now'],
#  ['AXP',
#   'Aug-11-22',
#   '09:30AM',
#   'American Express and Break the Love Partner to Offer 10,000 Complimentary Court Reservations to All NYC Area Tennis Fans Ahead of the US Open'],
#  ['AXP',
#   'Aug-11-22',
#   '12:00AM',
#   'Africas $3 Billion Startup Battles Allegations as It Plans IPO'],
#  ['AXP',
#   'Aug-10-22',
#   '06:45PM',
#   'Issa Rae Headlines American Express Business Class LIVE 2022'],
#  ['AXP',
#   'Aug-10-22',
#   '11:30AM',
#   'ClearBridge Investments Remains Confident About American Express Company (AXP)'],
#  ['AXP',
#   'Aug-10-22',
#   '09:00AM',
#   'Top New York Restaurants - Bonnies, Crown Shy, Dhamaka, Taqueria Ramirez, Razza, Sofreh and more - Join Forces with The American Express® Gold Card and Resy for Two-Night Drive-Thru Dining Event'],
#  ['AXP',
#   'Aug-10-22',
#   '06:30AM',
#   '3 Warren Buffett Stocks to Buy Hand Over Fist in August'],
#  ['AXP',
#   'Aug-09-22',
#   '06:13AM',
#   'What Is The Ownership Structure Like For American Express Company (NYSE:AXP)?'],
#  ['AXP',
#   'Aug-08-22',
#   '06:00AM',
#   '7 Beaten-Down Dow Stocks to Buy Before They Rebound'],
#  ['AXP',
#   'Aug-06-22',
#   '06:58AM',
#   'This Dividend Stock Will Hold Up No Matter the Market Conditions'],
#  ['AXP',
#   'Aug-05-22',
#   '08:51AM',
#   'Inflation is impacting consumers very differently: A little bit of a tale of two cities'],
#  ['AXP',
#   'Aug-04-22',
#   '07:10AM',
#   'American Express Releases 2021-2022 Environmental, Social and Governance (ESG) Report'],
#  ['AXP',
#   'Aug-03-22',
#   '07:50AM',
#   'Winners and Losers From Card-Fee Proposal Are Hard to Figure'],
#  ['AXP',
#   'Aug-02-22',
#   '11:32AM',
#   "Marriott CEO: Earnings indicate the broad 'resilience of travel'"],
#  ['AXP',
#   'Aug-02-22',
#   '09:00AM',
#   'American Express® Launches Digital, Cross-Border Payment Solution for U.S. Small Businesses'],
#  ['AXP',
#   'Aug-02-22',
#   '05:30AM',
#   'Banks Spend Big to Boost Credit-Card Sign-Ups, Defying Recession Fears'],
#  ['AXP',
#   'Jul-31-22',
#   '10:53AM',
#   'These Beaten-Down Stocks Could Reap Monster Returns From Strong Consumer Spending'],
#  ['AXP', 'Jul-31-22', '07:30AM', '2 Dow Stocks to Buy More of in August'],
#  ['AXP',
#   'Jul-30-22',
#   '06:30AM',
#   '2 Stocks That Might Be Stronger Than You Think'],
#  ['AXP',
#   'Jul-29-22',
#   '05:06AM',
#   "80% of Warren Buffett's Portfolio Is Invested in These 7 Stocks"],
#  ['AXP',
#   'Jul-28-22',
#   '09:06AM',
#   'Mastercard Earnings Beat Estimates, Showing No Sign of Recession Fears  Yet'],
#  ['AXP',
#   'Jul-28-22',
#   '08:09AM',
#   'Mastercard Stock Edges Higher As Spending Surge Drives Q2 Earnings Beat'],
#  ['AXP',
#   'Jul-28-22',
#   '05:10AM',
#   'A Rebound in Travel and Entertainment Is Fueling This Longtime Warren Buffett Stock'],
#  ['AXP',
#   'Jul-27-22',
#   '03:57PM',
#   'How I Got 50% Off a Big Purchase by Combining a Credit Card Promo With a Prime Day Deal'],
#  ['AXP',
#   'Jul-27-22',
#   '01:28PM',
#   'These Companies Stand to Profit The Most From Interest Rate Hikes'],
#  ['AXP',
#   'Jul-27-22',
#   '01:23PM',
#   'Visa Stock Slumps On Senate Competition Bill Report, Clouding Q3 Earnings Beat'],
#  ['AXP',
#   'Jul-27-22',
#   '10:53AM',
#   'This Beaten Down Stock Could Serve Up Prime Returns'],
#  ['AXP',
#   'Jul-27-22',
#   '10:31AM',
#   'Senates Antitrust Crackdown Sputters as Schumer Signals Doubts'],
#  ['AXP',
#   'Jul-27-22',
#   '05:10AM',
#   'How Would American Express Fare During a Recession?'],
#  ['AXP',
#   'Jul-26-22',
#   '05:56PM',
#   'Visa Tops Q3 Earnings, Revenue Views Amid Strong Travel Spending; Is Visa Stock A Buy?'],
#  ['AXP', 'Jul-26-22', '05:12PM', 'Visa Earnings Gain as Travel Comes Back'],
#  ['AXP',
#   'Jul-26-22',
#   '06:00AM',
#   '4 Credit Card Companies That Offer Free Identity Protection'],
#  ['AXP',
#   'Jul-26-22',
#   '05:59AM',
#   'The Zacks Analyst Blog Highlights Amazon, Walmart, Bank of America, American Express, and SAP'],
#  ['AXP',
#   'Jul-26-22',
#   '02:00AM',
#   'Why wont Amex or BA give us our £1,350 flight refund?'],
#  ['AXP',
#   'Jul-25-22',
#   '05:04PM',
#   'Top Stock Reports for Amazon.com, Walmart & Bank of America'],
#  ['AXP', 'Jul-25-22', '09:25AM', 'Company News for Jul 25, 2022'],
#  ['AXP',
#   'Jul-25-22',
#   '06:37AM',
#   'Why the stock market has defied the odds in July (so far)'],
#  ['AXP',
#   'Jul-25-22',
#   '05:06AM',
#   '15 Stocks Warren Buffett Has Held for at Least 10 Years'],
#  ['AXP',
#   'Jul-23-22',
#   '09:45PM',
#   'Quarter of homeowners have abandoned garden makeovers, poll finds'],
#  ['AXP',
#   'Jul-23-22',
#   '12:00PM',
#   '7 S&P 500 Stocks Trading at a Huge Discount Right Now'],
#  ['AXP',
#   'Jul-23-22',
#   '09:30AM',
#   'Impatience Can Be Costly During Bear Markets'],
#  ['AXP',
#   'Jul-22-22',
#   '04:55PM',
#   'Almost half of Americans expect to rack up more debt in the next six months: Report'],
#  ['AXP',
#   'Jul-22-22',
#   '04:52PM',
#   'Consumers Go Down Market to Keep Racking Up Credit Card Debt'],
#  ['AXP',
#   'Jul-22-22',
#   '04:36PM',
#   'US STOCKS-Wall Street closes lower as ad tech, social media stocks drop'],
#  ['AXP',
#   'Jul-22-22',
#   '04:26PM',
#   'Stock Market Today - 7/22: Stocks End Lower As Recession Fears, Snap Warning Rattle Markets'],
#  ['AXP',
#   'Jul-22-22',
#   '04:17PM',
#   "Stock Market Today: Stocks' Momentum Stalls After Shocking Snap Earnings"],
#  ['AXP',
#   'Jul-22-22',
#   '04:01PM',
#   'American Express Raises Guidance After Major Earnings Beat'],
#  ['AXP',
#   'Jul-22-22',
#   '02:00PM',
#   'Dow Jones Loses Early Gains, Nasdaq Sinks 2%; Will AmEx Finish A New Base?'],
#  ['AXP',
#   'Jul-22-22',
#   '01:15PM',
#   'American Express (AXP) Q2 Earnings Beat on Higher Spending'],
#  ['AXP',
#   'Jul-22-22',
#   '12:36PM',
#   'Stock Market Today - 7/22: Stocks Lower As Recession Fears, Snap Warning Rattle Markets'],
#  ['AXP',
#   'Jul-22-22',
#   '12:35PM',
#   'Stock Market Erases Early Gains; Snap And Verizon Fall On Poor Earnings'],
#  ['AXP',
#   'Jul-22-22',
#   '11:30AM',
#   'American Express (AXP) Q2 2022 Earnings Call Transcript'],
#  ['AXP', 'Jul-22-22', '10:49AM', 'Earnings Data Deluge'],
#  ['AXP',
#   'Jul-22-22',
#   '10:42AM',
#   'Stock Market Today: Track Market Trends And The Best Stocks To Watch'],
#  ['AXP',
#   'Jul-22-22',
#   '10:34AM',
#   'Dow Jones Edges Up In Mixed Open; Social Media Stocks Tank As Earnings Rock The Boat'],
#  ['AXP',
#   'Jul-22-22',
#   '10:21AM',
#   'Markets Look to Finish Another Up-Week; AMX, TWTR in Different Q2 Directions'],
#  ['AXP',
#   'Jul-22-22',
#   '10:15AM',
#   'Stocks mixed, Treasury yields down, Snap stock plummets'],
#  ['AXP',
#   'Jul-22-22',
#   '09:52AM',
#   'Dow Jones Rises, Tech Stocks Slip As Snap Crashes 33% On Earnings'],
#  ['AXP',
#   'Jul-22-22',
#   '09:40AM',
#   'AmEx Sees Spending Soar as Travel Rises Despite Airline Woes'],
#  ['AXP',
#   'Jul-22-22',
#   '09:39AM',
#   'American Express CEO: I do not see a recession'],
#  ['AXP',
#   'Jul-22-22',
#   '09:11AM',
#   'US STOCKS-Social media stocks set to weigh on S&P 500, Nasdaq at open'],
#  ['AXP',
#   'Jul-22-22',
#   '09:03AM',
#   'American Express Stock Surges After Crushing Q2 Profit Forecast Amid Record Card Spending'],
#  ['AXP',
#   'Jul-22-22',
#   '08:21AM',
#   'American Express Revenue Up 31% as Spending Remains Robust'],
#  ['AXP',
#   'Jul-22-22',
#   '08:15AM',
#   'American Express (AXP) Tops Q2 Earnings and Revenue Estimates'],
#  ['AXP',
#   'Jul-22-22',
#   '08:13AM',
#   "'Don't see it in my numbers': American Express CEO doubts recession fears"],
#  ['AXP',
#   'Jul-22-22',
#   '08:10AM',
#   'Snap, Twitter, GameStop, and More Stock Market Movers Friday'],
#  ['AXP',
#   'Jul-22-22',
#   '07:51AM',
#   "Stock market news live updates: Stock futures mixed ahead of week's final trading day"],
#  ['AXP',
#   'Jul-22-22',
#   '07:24AM',
#   'UPDATE 1-AmEx raises revenue forecast on resilient card spending'],
#  ['AXP',
#   'Jul-22-22',
#   '07:18AM',
#   'AmEx raises revenue forecast on resilient card spending'],
#  ['AXP',
#   'Jul-22-22',
#   '07:08AM',
#   'Amex shrugs off macro fears with huge earnings beat powered by strong spending'],
#  ['AXP',
#   'Jul-22-22',
#   '07:00AM',
#   'American Express Second-Quarter Revenue Increases 31% to $13.4 Billion'],
#  ['AXP',
#   'Jul-22-22',
#   '06:00AM',
#   'A key point being lost amid fears of an economic slowdown: Morning Brief'],
#  ['AXP', 'Jul-21-22', '11:54AM', '10 Best Dividend Stocks to Buy in 2022'],
#  ['AXP',
#   'Jul-21-22',
#   '11:52AM',
#   'Verizon, American Express, Twitter Earnings: 3 Things to Watch'],
#  ['AXP',
#   'Jul-21-22',
#   '10:08AM',
#   'Consumer Spending Shows Shifts in Spending Power,\xa0Priorities'],
#  ['AMGN',
#   'Sep-01-22',
#   '10:59AM',
#   "How Covid, 'industrial logic' and a threat played out in a multibillion-dollar biotech merger"],
#  ['AMGN',
#   'Aug-31-22',
#   '04:09PM',
#   "Why Amgen's Cancer Drug Results Gave This Small Cap A Big Boost"],
#  ['AMGN',
#   'Aug-31-22',
#   '12:12PM',
#   "Amgen's (AMGN) Lumakras Meets Goal in New Lung Cancer Study"],
#  ['AMGN', 'Aug-31-22', '09:53AM', 'What This News Might Mean for Amgen'],
#  ['AMGN',
#   'Aug-30-22',
#   '04:03PM',
#   'AMGEN ANNOUNCES TOPLINE DATA FROM LUMAKRAS® (SOTORASIB) PHASE 3 TRIAL IN NON-SMALL CELL LUNG CANCER'],
#  ['AMGN',
#   'Aug-30-22',
#   '11:22AM',
#   "Amgen (AMGN) Outperforms Industry Year to Date: What's Next?"],
#  ['AMGN',
#   'Aug-30-22',
#   '09:00AM',
#   'AMGEN TO PRESENT NEW, POSITIVE CLINICAL AND REAL-WORLD DATA ACROSS INFLAMMATION PORTFOLIO AT EADV 2022'],
#  ['AMGN',
#   'Aug-29-22',
#   '08:55AM',
#   "Amgen's Repatha Shows Long Term Lowering Of Bad Cholesterol, Tolerance"],
#  ['AMGN',
#   'Aug-29-22',
#   '05:56AM',
#   'Why Dividend Stocks Could Soon Be More Attractive -- Thanks to Joe Biden'],
#  ['AMGN',
#   'Aug-29-22',
#   '03:10AM',
#   'NEW AMGEN DATA AT ESC 2022 SHOW LONG-TERM LDL-C LOWERING WITH REPATHA® (EVOLOCUMAB) WAS WELL-TOLERATED FOR MORE THAN 8 YEARS'],
#  ['AMGN',
#   'Aug-25-22',
#   '12:02PM',
#   'Take Advantage Of Low Volatility In Amgen Stock With Options'],
#  ['AMGN',
#   'Aug-25-22',
#   '09:51AM',
#   'Dow Jones Falls After Key Economic Data; Peloton Dives 18% On Earnings'],
#  ['AMGN',
#   'Aug-24-22',
#   '01:33PM',
#   "Amgen (AMGN) Posts Positive Data from Soliris' Biosimilar Study"],
#  ['AMGN',
#   'Aug-24-22',
#   '09:58AM',
#   'Dow Jones Falls As Tesla Climbs Ahead Of 3:1 Stock Split'],
#  ['AMGN',
#   'Aug-24-22',
#   '08:40AM',
#   '2 Top Biotech Stocks to Buy for the Long Haul'],
#  ['AMGN',
#   'Aug-23-22',
#   '11:43AM',
#   'Amgen Touts Positive Data From Soliris-Based Biosimilar For Rare Blood Disorder'],
#  ['AMGN',
#   'Aug-23-22',
#   '10:02AM',
#   'Dow Jones Falls After Stock Market Plunge; Zoom Video Dives On Earnings'],
#  ['AMGN',
#   'Aug-23-22',
#   '09:00AM',
#   'AMGEN ANNOUNCES POSITIVE TOP-LINE RESULTS FROM PHASE 3 STUDY OF ABP 959, BIOSIMILAR CANDIDATE TO SOLIRIS® (ECULIZUMAB)'],
#  ['AMGN',
#   'Aug-22-22',
#   '09:00AM',
#   'AMGEN TO PRESENT NEW DATA AT ESC CONGRESS 2022 HIGHLIGHTING UP TO 8.5 YEARS OF REPATHA® (EVOLOCUMAB) SAFETY AND TOLERABILITY DATA IN HIGH-RISK ASCVD PATIENT POPULATIONS'],
#  ['AMGN',
#   'Aug-18-22',
#   '08:00AM',
#   'How Are Biotech ETFs Reacting to Q2 Earnings Releases?'],
#  ['AMGN',
#   'Aug-16-22',
#   '01:23PM',
#   'Retail Scorecard and Analyst Reports for Coca-Cola, Oracle & Morgan Stanley'],
#  ['AMGN',
#   'Aug-16-22',
#   '09:40AM',
#   'Are You a Value Investor? This 1 Stock Could Be the Perfect Pick'],
#  ['AMGN',
#   'Aug-16-22',
#   '08:07AM',
#   "Amgen Moves to Dismiss Regeneron's Antitrust Case Regarding Cholesterol Drug"],
#  ['AMGN',
#   'Aug-15-22',
#   '10:40AM',
#   'Biotech Keeps Staving Off the Bear, but for How Long?'],
#  ['AMGN',
#   'Aug-15-22',
#   '10:35AM',
#   "Amgen Inc. -- Moody's assigns Baa1 rating to Amgen's notes; stable outlook"],
#  ['AMGN',
#   'Aug-13-22',
#   '08:19AM',
#   "Only Three Days Left To Cash In On Amgen's (NASDAQ:AMGN) Dividend"],
#  ['AMGN',
#   'Aug-12-22',
#   '02:04PM',
#   "Senate Finance Committee Expands Amgen's Tax Probe: Report"],
#  ['AMGN',
#   'Aug-12-22',
#   '06:05AM',
#   'The Zacks Analyst Blog Highlights Amgen, ChemoCentryx, Mersana Therapeutics, GSK and Vertex Pharmaceuticals'],
#  ['AMGN',
#   'Aug-11-22',
#   '03:01PM',
#   'Fed Isnt Popping Champagne (Capital Market Research) (Weekly Market Outlook)'],
#  ['AMGN',
#   'Aug-11-22',
#   '01:39PM',
#   'Senate Finance Committee looks at Amgen taxes, widening drugmaker probe'],
#  ['AMGN',
#   'Aug-11-22',
#   '01:33PM',
#   'Senate Finance Committee looks at Amgen taxes, widening drugmaker probe'],
#  ['AMGN',
#   'Aug-11-22',
#   '11:25AM',
#   "Biotech Stock Roundup: AMGN's Q2 Earnings, CCXI Acquisition & More Updates"],
#  ['AMGN',
#   'Aug-09-22',
#   '04:46PM',
#   'Get ready for more merger mania in the pharma sector for the rest of the year'],
#  ['AMGN',
#   'Aug-08-22',
#   '02:17PM',
#   'AMGEN PRESENTS NEW TARLATAMAB CLINICAL DATA AT WCLC 2022'],
#  ['AMGN',
#   'Aug-08-22',
#   '11:11AM',
#   "Amgen's Lumakras/Keytruda/Tecentriq Combo Data Flags Safety Concern"],
#  ['AMGN',
#   'Aug-07-22',
#   '04:10AM',
#   'Amgen says Lumakras plus immunotherapy for lung cancer needs further study'],
#  ['AMGN',
#   'Aug-07-22',
#   '04:10AM',
#   'AMGEN DATA AT WCLC 2022 HIGHLIGHTS POTENTIAL TO DELIVER TRANSFORMATIVE MEDICINES FOR HISTORICALLY DIFFICULT-TO-TREAT LUNG CANCERS'],
#  ['AMGN',
#   'Aug-07-22',
#   '12:49AM',
#   'How Amgen Makes Billions On Just A Few Drugs'],
#  ['AMGN',
#   'Aug-05-22',
#   '05:16PM',
#   'Amgen Narrows Sales Outlook Following Plans To Acquire ChemoCentryx'],
#  ['AMGN',
#   'Aug-05-22',
#   '09:45AM',
#   'Amgen (AMGN) Beats Q2 Earnings Estimates, to Buy Chemocentryx'],
#  ['AMGN',
#   'Aug-05-22',
#   '08:16AM',
#   'DraftKings, Zillow, Lyft, AMC, and Other Stock Market Movers'],
#  ['AMGN',
#   'Aug-05-22',
#   '08:14AM',
#   "Amgen's Q2 Sales Impacted By Lower Prices, Currency Headwind, Reaffirms FY22 Outlook"],
#  ['AMGN',
#   'Aug-05-22',
#   '08:12AM',
#   "Dow Jones Futures: Jobs Report Tests 'Soft Landing' Market Rally; Tesla Stock Split Approved"],
#  ['AMGN',
#   'Aug-04-22',
#   '07:10PM',
#   'ChemoCentrix Spikes 110% on Amgen Acquisition Deal'],
#  ['AMGN',
#   'Aug-04-22',
#   '05:25PM',
#   'Amgen (AMGN) Q2 Earnings and Revenues Beat Estimates'],
#  ['AMGN',
#   'Aug-04-22',
#   '05:23PM',
#   'Amgen to buy ChemoCentryx for billions in cash'],
#  ['AMGN',
#   'Aug-04-22',
#   '04:18PM',
#   'Amgen Aims To Stanch Generic Losses With $3.7 Billion ChemoCentryx Buyout'],
#  ['AMGN',
#   'Aug-04-22',
#   '04:01PM',
#   'AMGEN REPORTS SECOND QUARTER 2022 FINANCIAL RESULTS'],
#  ['AMGN',
#   'Aug-04-22',
#   '11:35AM',
#   'Amgen Acquires Drugmaker ChemoCentryx for $3.7 Billion'],
#  ['AMGN',
#   'Aug-04-22',
#   '11:16AM',
#   'Big biotech to buy one-drug Peninsula company ChemoCentryx for $3.7 billion cash'],
#  ['AMGN', 'Aug-04-22', '10:08AM', 'Why ChemoCentryx Stock Is On Fire Today'],
#  ['AMGN',
#   'Aug-04-22',
#   '09:05AM',
#   'ChemoCentryx Stock More Than Doubles On $4B Buyout'],
#  ['AMGN',
#   'Aug-04-22',
#   '08:24AM',
#   'Amgen to gain rare-disease drug in $3.7 billion acquisition of ChemoCentryx'],
#  ['AMGN',
#   'Aug-04-22',
#   '08:17AM',
#   "Amgen bets on ChemoCentryx's rare disease drug in $3.7 billion deal"],
#  ['AMGN',
#   'Aug-04-22',
#   '08:15AM',
#   "UPDATE 4-Amgen bets on ChemoCentryx's rare disease drug in $3.7 bln deal"],
#  ['AMGN',
#   'Aug-04-22',
#   '08:00AM',
#   'Amgen to Buy ChemoCentryx for $3.7 Billion'],
#  ['AMGN',
#   'Aug-04-22',
#   '08:00AM',
#   'AMGEN TO ACQUIRE CHEMOCENTRYX FOR $4 BILLION IN CASH'],
#  ['AMGN',
#   'Aug-03-22',
#   '04:05PM',
#   'AMGEN APPOINTS MICHAEL V. DRAKE TO BOARD OF DIRECTORS'],
#  ['AMGN',
#   'Aug-03-22',
#   '04:00PM',
#   'AMGEN ANNOUNCES 2022 THIRD QUARTER DIVIDEND'],
#  ['AMGN',
#   'Aug-03-22',
#   '10:38AM',
#   'Companies That Offer the Biggest 401(k) Employer Match'],
#  ['AMGN',
#   'Aug-02-22',
#   '04:00PM',
#   'AMGEN TO WEBCAST INVESTOR MEETING AT WCLC 2022'],
#  ['AMGN',
#   'Aug-01-22',
#   '04:00PM',
#   'AMGEN ANNOUNCES WEBCAST OF 2022 SECOND QUARTER FINANCIAL RESULTS'],
#  ['AMGN',
#   'Aug-01-22',
#   '10:01AM',
#   'Analysts Estimate Heska (HSKA) to Report a Decline in Earnings: What to Look Out for'],
#  ['AMGN',
#   'Aug-01-22',
#   '10:00AM',
#   "Amgen (AMGN) to Report Q2 Earnings: What's in the Cards?"],
#  ['AMGN',
#   'Aug-01-22',
#   '07:56AM',
#   'Amgen To Fight IRS Agency Over Tax Bill Of Whooping $10.7B: Report'],
#  ['AMGN',
#   'Aug-01-22',
#   '05:30AM',
#   'Amgen Fights IRS Over $10.7 Billion Tax Bill'],
#  ['AMGN',
#   'Jul-30-22',
#   '10:00AM',
#   'Starbucks, Uber, CVS to Report Earnings Amid Shrinking Economy'],
#  ['AMGN',
#   'Jul-28-22',
#   '05:50PM',
#   'Amgen (AMGN) Stock Sinks As Market Gains: What You Should Know'],
#  ['AMGN',
#   'Jul-28-22',
#   '05:45PM',
#   '3 Healthcare Stocks With 3%+ Dividend Yields'],
#  ['AMGN',
#   'Jul-28-22',
#   '10:02AM',
#   'Amgen (AMGN) Reports Next Week: Wall Street Expects Earnings Growth'],
#  ['AMGN',
#   'Jul-27-22',
#   '10:18AM',
#   'Stocks: Tech leads gains, home builders fall, Sherwin-Williams sinks'],
#  ['AMGN',
#   'Jul-26-22',
#   '04:42PM',
#   'Drugmakers Hope New Heart Drugs Boost Sales, Revive Market'],
#  ['AMGN',
#   'Jul-23-22',
#   '08:02AM',
#   'Dow Jones Giant Amgen Leads 5 Stocks To Watch Near Buy Points'],
#  ['AMGN',
#   'Jul-22-22',
#   '05:50PM',
#   'Amgen (AMGN) Gains As Market Dips: What You Should Know'],
#  ['AMGN',
#   'Jul-21-22',
#   '02:00PM',
#   'Highly Rated Amgen Stock Near Buy Zone With Earnings Due'],
#  ['AMGN',
#   'Jul-21-22',
#   '11:15AM',
#   'Healthcare ETFs in Focus Ahead of Q2 Earnings'],
#  ['AMGN',
#   'Jul-21-22',
#   '09:45AM',
#   '2 Rock-Solid Dividend Stocks to Buy Right Now'],
#  ['AMGN', 'Jul-20-22', '06:00PM', '7 Best Pharmaceutical Stocks to Buy Now'],
#  ['AMGN',
#   'Jul-20-22',
#   '06:00PM',
#   'Amgen (AMGN) Stock Sinks As Market Gains: What You Should Know'],
#  ['AMGN',
#   'Jul-20-22',
#   '10:30AM',
#   '2 Dividend Growth Stocks to Buy and Hold for Decades'],
#  ['AMGN',
#   'Jul-19-22',
#   '10:15AM',
#   'Is Trending Stock Amgen Inc. (AMGN) a Buy Now?'],
#  ['AMGN',
#   'Jul-15-22',
#   '12:10PM',
#   'Why Amgen (AMGN) Could Beat Earnings Estimates Again'],
#  ['AMGN',
#   'Jul-15-22',
#   '11:07AM',
#   '2 Biotech Stocks You Can Buy and Hold for the Next Decade'],
#  ['AMGN',
#   'Jul-15-22',
#   '07:50AM',
#   '3 Biotech Stocks Outperforming a Bear Market'],
#  ['AMGN',
#   'Jul-14-22',
#   '05:50PM',
#   'Amgen (AMGN) Dips More Than Broader Markets: What You Should Know'],
#  ['AMGN',
#   'Jul-13-22',
#   '06:00PM',
#   'Amgen (AMGN) Gains As Market Dips: What You Should Know'],
#  ['AMGN',
#   'Jul-13-22',
#   '01:41PM',
#   'Amgen Touts Early Lumakras Combo Data In KRAS Cancer Settings'],
#  ['AMGN',
#   'Jul-12-22',
#   '06:00PM',
#   "UPDATE 1-Amgen's Lumakras/immunotherapy combo data held for August lung cancer meeting"],
#  ['AMGN',
#   'Jul-12-22',
#   '02:19PM',
#   "Amgen's Lumakras combination data held for August lung cancer meeting"],
#  ['AMGN',
#   'Jul-11-22',
#   '04:14PM',
#   'Pharma Rally Continues As Pfizer, Amgen Look To Break Out, Pulling Rivals With Them'],
#  ['AMGN', 'Jul-08-22', '07:35AM', '7 Best Biotech Stocks to Buy in July 2022'],
#  ['AMGN',
#   'Jul-07-22',
#   '05:50PM',
#   'Amgen (AMGN) Gains But Lags Market: What You Should Know'],
#  ['AMGN',
#   'Jul-07-22',
#   '02:38PM',
#   'Biotechs Say ESG Is Core To Their Mission; Do Investors Believe Them?'],
#  ['AMGN',
#   'Jul-06-22',
#   '09:59AM',
#   'Dow 30 Stocks Listed and Ranked By 2022 Hedge Fund Bullishness Index'],
#  ['AMGN',
#   'Jul-05-22',
#   '06:00PM',
#   'Amgen (AMGN) Outpaces Stock Market Gains: What You Should Know'],
#  ['AMGN',
#   'Jul-05-22',
#   '09:47AM',
#   'Is Most-Watched Stock Amgen Inc. (AMGN) Worth Betting on Now?'],
#  ['AMGN',
#   'Jul-01-22',
#   '10:00AM',
#   "Amgen's Beating the Market -- Here's Why It's a Buy Now"],
#  ['AMGN',
#   'Jul-01-22',
#   '07:26AM',
#   "What You Need To Know About Amgen Inc.'s (NASDAQ:AMGN) Investor Composition"],
#  ['AMGN',
#   'Jun-30-22',
#   '05:37PM',
#   'Here Are The 5 Best Dow Jones Stocks So Far This Year Amid Market Sell-Off'],
#  ['AMGN',
#   'Jun-28-22',
#   '05:50PM',
#   'Amgen (AMGN) Stock Moves -0.55%: What You Should Know'],
#  ['AAPL',
#   'Sep-02-22',
#   '12:30AM',
#   'Why a Bearish Money Manager Likes Gambling Stocks and Is Ready to Dump Apple'],
#  ['AAPL',
#   'Sep-02-22',
#   '12:00AM',
#   'Apple overtakes Android to pass 50% share of smartphones used in US'],
#  ['AAPL',
#   'Sep-01-22',
#   '06:28PM',
#   'Broadcom Gives Strong Forecast, Evading the Chip Slump'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:56PM',
#   'Apple Employees in Oklahoma City Petition to Unionize Store'],
#  ['AAPL', 'Sep-01-22', '05:19PM', 'Where Will Snap Stock Be in 1 Year?'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:01PM',
#   'UK regulators concerned about Microsoft-Activision Blizzard deal, more parents buying Apple Watches'],
#  ['AAPL', 'Sep-01-22', '05:00PM', 'My Favorite Tech Stock for a Hawkish Fed'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:00PM',
#   'Japans King of Deals Preps His Biggest Buy in Yen Headwinds'],
#  ['AAPL',
#   'Sep-01-22',
#   '04:12PM',
#   'Music platforms agree to deal with songwriters and publishers, streaming services opt for bundles'],
#  ['AAPL',
#   'Sep-01-22',
#   '02:23PM',
#   'You need quality stocks during times of turmoil. Heres one good strategy for picking them'],
#  ['AAPL',
#   'Sep-01-22',
#   '02:06PM',
#   'Apartments planned near Apple campus site in Morrisville'],
#  ['AAPL',
#   'Sep-01-22',
#   '02:05PM',
#   'iPhone 14 Pro: Late rumour could explain how Apple intends to use odd new display design'],
#  ['AAPL',
#   'Sep-01-22',
#   '02:01PM',
#   'Nasdaq Leads Losses As Jobless Claims Fall, Stock Market Off Lows; Tech, Energy Pummeled'],
#  ['AAPL', 'Sep-01-22', '12:00PM', '3 "Keep It Simple" Stocks to Buy Today'],
#  ['AAPL',
#   'Sep-01-22',
#   '11:52AM',
#   'Apple, Tesla and Amazon stocks in danger of 1st closes below 50-DMAs in nearly 2 months'],
#  ['AAPL',
#   'Sep-01-22',
#   '11:52AM',
#   'Watch: Southwest pilot warns passengers to quit sending naked pictures over AirDrop, or its everyone off the plane!'],
#  ['AAPL',
#   'Sep-01-22',
#   '11:48AM',
#   'Dow Jones Pares Losses But Nasdaq Drop Worsens As Yields Jump; Steel, Energy, EV Stocks Slide; Apple Tests Key Level'],
#  ['AAPL',
#   'Sep-01-22',
#   '11:32AM',
#   "Top Millennial Pick Tesla's China August Sales Seen Rebounding To 77,000"],
#  ['AAPL',
#   'Sep-01-22',
#   '11:20AM',
#   "Don't be duped by the doom-n-gloom: JPMorgan says this reliable contrarian indicator points to an 11% stock market surge  here are 3 ways to play it"],
#  ['AAPL',
#   'Sep-01-22',
#   '07:44AM',
#   'Nvidia Ensnared in Geopolitical Spy Games With China Export Ban'],
#  ['AAPL',
#   'Sep-01-22',
#   '06:05AM',
#   '2 Market-Beating Dividend Stocks for Passive Income Investors to Buy Now'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:59AM',
#   'When is the Apple event 2022? The iPhone 14 and new Watch release date has been revealed'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:52AM',
#   '3 No-Brainer Warren Buffett Stocks to Buy in September'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:10AM',
#   '2 Stock-Split Stocks to Buy Hand Over Fist Amid the Market Sell-Off'],
#  ['AAPL',
#   'Sep-01-22',
#   '05:05AM',
#   'China iPhone Assembler Accused of Secretly Acquiring Taiwan Tech'],
#  ['AAPL',
#   'Aug-31-22',
#   '10:08PM',
#   'Apple already decimated Metas ad-tech empire. Now, its homing in on Facebooks advertisers, too.'],
#  ['AAPL',
#   'Aug-31-22',
#   '09:42PM',
#   'Meta exploring more paid features to make up for lost ad revenue: report'],
#  ['AAPL',
#   'Aug-31-22',
#   '07:26PM',
#   'SoftBanks Arm Is\xa0Suing Qualcomm for Licensing and Trademark Violations'],
#  ['AAPL', 'Aug-31-22', '06:58PM', '5 Big Tech Stocks That Are Bargains Now'],
#  ['AAPL',
#   'Aug-31-22',
#   '05:38PM',
#   'Apple, HTC cleared in U.S. trade tribunal dispute over wireless patents'],
#  ['AAPL', 'Aug-31-22', '04:52PM', 'Top Tech Stocks for September 2022'],
#  ['AAPL',
#   'Aug-31-22',
#   '04:40PM',
#   'Brussels proposes tough regulations on smartphone spare part availability'],
#  ['AAPL',
#   'Aug-31-22',
#   '04:37PM',
#   'Analyst: Apple stock is a Buy ahead of the inflationary iPhone 14 release'],
#  ['AAPL',
#   'Aug-31-22',
#   '04:20PM',
#   'Stocks close in on a losing month, energy and utilities sectors lead intraday gains'],
#  ['AAPL',
#   'Aug-31-22',
#   '02:24PM',
#   'Snap Will Cut 20% of Workforce, Slash Investments, Add COO'],
#  ['AAPL',
#   'Aug-31-22',
#   '12:11PM',
#   'iPhone 14: Apple to add bigger pixels to camera in new phone, report claims'],
#  ['AAPL',
#   'Aug-31-22',
#   '11:58AM',
#   'Dont forget that the big money in stocks is usually made during down markets'],
#  ['AAPL',
#   'Aug-31-22',
#   '11:43AM',
#   'Apple and Meta need to win over the enterprise if the metaverse is going to succeed'],
#  ['AAPL',
#   'Aug-31-22',
#   '11:40AM',
#   'Metaverse success depends on corporate adoption'],
#  ['AAPL',
#   'Aug-31-22',
#   '10:37AM',
#   "Congress urges firms to fight crypto fraud, Apple's privacy head departs, Army grounds helicopters"],
#  ['AAPL', 'Aug-31-22', '10:33AM', 'TikTok and Instagrams most popular stocks'],
#  ['AAPL',
#   'Aug-31-22',
#   '09:35AM',
#   'An Ominous Month Looms For Battered Nasdaq Bulls'],
#  ['AAPL',
#   'Aug-31-22',
#   '08:45AM',
#   "Nasdaq Bear Market: 2 Growth Stocks You'll Wish You'd Bought on the Dip"],
#  ['AAPL',
#   'Aug-31-22',
#   '08:35AM',
#   'Apple October event: iPads, Macs and everything we expect to be announced after the iPhone 14 and Watch'],
#  ['AAPL',
#   'Aug-31-22',
#   '08:13AM',
#   "Dow Jones Futures Signal Market Rally Isn't Finished After Key Support Broken"],
#  ['AAPL',
#   'Aug-31-22',
#   '05:06AM',
#   "86% of Warren Buffett's Portfolio Is Invested in These 10 Stocks"],
#  ['AAPL',
#   'Aug-31-22',
#   '01:29AM',
#   'More young, middle-class Americans flock to dollar stores, seeking a refuge from record-high inflation'],
#  ['AAPL',
#   'Aug-31-22',
#   '12:41AM',
#   'Apple Quietly Gives Up Its Didi Board Seat After Turmoil'],
#  ['AAPL',
#   'Aug-30-22',
#   '09:36PM',
#   'Apple chief privacy officer set to leave company for law firm -Bloomberg News'],
#  ['AAPL',
#   'Aug-30-22',
#   '09:28PM',
#   'Apple privacy chief Jane Horvath is reportedly stepping down'],
#  ['AAPL',
#   'Aug-30-22',
#   '09:24PM',
#   'Apple chief privacy officer set to leave company for law firm -Bloomberg News'],
#  ['AAPL',
#   'Aug-30-22',
#   '07:39PM',
#   'Apples Chief Privacy Officer Set to Leave Company for Law Firm'],
#  ['AAPL',
#   'Aug-30-22',
#   '06:34PM',
#   'Why Apple, Meta Platforms, and Salesforce Stocks Traded Lower on Tuesday'],
#  ['AAPL',
#   'Aug-30-22',
#   '03:52PM',
#   'Tech stocks: MATANA is the new FAANG, analyst says'],
#  ['AAPL',
#   'Aug-30-22',
#   '03:26PM',
#   'Im cutting back on social media  heres how you can too'],
#  ['AAPL',
#   'Aug-30-22',
#   '03:12PM',
#   'Is PTON Stock A Buy Or Sell After Big Loss, Amazon Partnership?'],
#  ['AAPL',
#   'Aug-30-22',
#   '12:25PM',
#   'Tom Hanks Is Launching a Trivia Game Exclusively on Apple Arcade'],
#  ['AAPL',
#   'Aug-30-22',
#   '11:51AM',
#   'iPhone 14: New Apple phone could have special satellite features, reports suggest'],
#  ['AAPL',
#   'Aug-30-22',
#   '10:55AM',
#   'Best Buy says pricey smartphone sales holding strong ahead of next iPhone launch'],
#  ['AAPL',
#   'Aug-30-22',
#   '10:24AM',
#   'Apple October event: iPads, Macs and everything we expect to be announced after the iPhone 14 and Watch'],
#  ['AAPL',
#   'Aug-30-22',
#   '09:56AM',
#   'Are Options Traders Betting on a Big Move in Apple (AAPL) Stock?'],
#  ['AAPL',
#   'Aug-29-22',
#   '10:27PM',
#   'Australia demands Apple, Meta, Microsoft share anti-abuse steps, threatens fines'],
#  ['AAPL',
#   'Aug-29-22',
#   '10:19PM',
#   'Australia demands Apple, Meta, Microsoft share anti-abuse steps, threatens fines'],
#  ['AAPL',
#   'Aug-29-22',
#   '06:30PM',
#   'Why the Shine Was off Apple Stock on Monday'],
#  ['AAPL',
#   'Aug-29-22',
#   '05:42PM',
#   'Why Globalstar Stock Soared 10% Higher Today Before Falling Back to Earth'],
#  ['AAPL', 'Aug-29-22', '04:46PM', '10 Best ADR Stocks To Buy Now'],
#  ['AAPL',
#   'Aug-29-22',
#   '04:22PM',
#   'Dow Jones Reverses; Elon Musk Makes This Twitter Move; Coinbase Falls As Bitcoin Rises'],
#  ['AAPL',
#   'Aug-29-22',
#   '03:13PM',
#   '10 Best Index Funds Popular Among Reddit Investors'],
#  ['AAPL', 'Aug-29-22', '02:24PM', 'Apple Is Not Out of the Woods Just Yet'],
#  ['AAPL',
#   'Aug-29-22',
#   '01:46PM',
#   'Apple May Add Satellite Connection to iPhones, Analyst Says'],
#  ['AAPL',
#   'Aug-29-22',
#   '12:30PM',
#   'Stocks headed for more pain as 3,900 becomes new line in the sand for the S&P 500, chart watchers say'],
#  ['AAPL',
#   'Aug-29-22',
#   '11:50AM',
#   'Apple rumored to release AR/VR headsets next year'],
#  ['AAPL',
#   'Aug-29-22',
#   '10:48AM',
#   'Apple, Alphabet, and Other Big Tech Stocks Extend Losses'],
#  ['AAPL',
#   'Aug-29-22',
#   '10:00AM',
#   'Dow Jones Falls After Powell-Fueled Stock Market Plunge; Apple, Tesla Skid'],
#  ['AAPL',
#   'Aug-29-22',
#   '09:45AM',
#   'This Under-the-Radar Apple Business Is Growing By Leaps and Bounds'],
#  ['AAPL', 'Aug-29-22', '09:45AM', 'The 2 Best Stocks to Buy Right Now'],
#  ['AAPL',
#   'Aug-29-22',
#   '09:39AM',
#   'Peloton and Zoom Show\xa0More Pain for Covid Trade'],
#  ['AAPL',
#   'Aug-29-22',
#   '09:38AM',
#   'Apple iPad faces longest lead time: JPMorgan report'],
#  ['AAPL',
#   'Aug-29-22',
#   '09:36AM',
#   'Trademark Filings Suggest Apple May Be Securing Reality Names for AR/VR\xa0Headset'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:40AM',
#   '5G Stocks To Buy And Watch As U.S. Plays Catch-Up Versus China'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:28AM',
#   "Dow Jones Futures Fall: Big Test For Indexes As Market Rally Feels Fed Chief Powell's 'Pain'"],
#  ['AAPL',
#   'Aug-29-22',
#   '08:20AM',
#   'Is Apple Stock A Buy Ahead Of iPhone 14 Launch Event?'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:11AM',
#   '10 Best Index Funds to Diversify Your Portfolio'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:04AM',
#   'Apple, Amazon, Meta, Coinbase, Boeing, and More Stock Market Movers Monday'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:03AM',
#   'Stocks: 3 tickers trending on Yahoo Finance'],
#  ['AAPL',
#   'Aug-29-22',
#   '08:00AM',
#   'NBCs Dateline Launches Apple Podcasts Subscription for True-Crime Buffs'],
#  ['AAPL',
#   'Aug-29-22',
#   '05:56AM',
#   'Why Dividend Stocks Could Soon Be More Attractive -- Thanks to Joe Biden'],
#  ['AAPL',
#   'Aug-28-22',
#   '03:07PM',
#   '10 Best Stocks to Invest Your $1000 According to Reddit'],
#  ['AAPL',
#   'Aug-28-22',
#   '01:00PM',
#   'Just as Wall Street Piles In, Tech Stocks Face Fresh Rates Storm'],
#  ['AAPL',
#   'Aug-28-22',
#   '10:53AM',
#   'My Top FAANG Stock to Buy for the Second Half of 2022 (and Beyond)'],
#  ['AAPL',
#   'Aug-28-22',
#   '09:00AM',
#   'You Love iPhone. Your Partner Loves Android. Heres How to Make It Work.'],
#  ['AAPL',
#   'Aug-27-22',
#   '09:42AM',
#   'Chinas Industrial Profit Falls on Covid-19 Measures, Bad Weather'],
#  ['AAPL',
#   'Aug-27-22',
#   '08:00AM',
#   'Dow Jones Giant Apple Leads Five Stocks To Watch Near Buy Points'],
#  ['AAPL',
#   'Aug-27-22',
#   '07:37AM',
#   '3 No-Brainer Warren Buffett Stocks to Buy Right Now'],
#  ['AAPL',
#   'Aug-27-22',
#   '07:20AM',
#   'Will Tesla Be Worth More Than Apple by 2030?'],
#  ['AAPL', 'Aug-27-22', '07:00AM', '2 FAANG Stocks to Buy Now and 1 to Avoid'],
#  ['AAPL', 'Aug-27-22', '05:00AM', 'Does Spotify Have a Moat?'],
#  ['AAPL', 'Aug-26-22', '06:29PM', 'Weekly Roundup'],
#  ['AAPL',
#   'Aug-26-22',
#   '04:16PM',
#   'Why Shopify, Amazon, and Apple Stocks Slumped Friday Morning'],
#  ['AAPL',
#   'Aug-26-22',
#   '04:11PM',
#   'Justice Department reportedly drafting antitrust suit against Apple'],
#  ['BA',
#   'Sep-02-22',
#   '03:25AM',
#   "Modi commissions India's first home-built aircraft carrier in defence push"],
#  ['BA', 'Sep-01-22', '02:07PM', 'Why Boeing Stock Is Falling Today'],
#  ['BA',
#   'Sep-01-22',
#   '01:52PM',
#   'Raytheon (RTX) Wins $972M Deal to Support AMRAAM Program'],
#  ['BA',
#   'Sep-01-22',
#   '01:28PM',
#   'Boeing (BA) Secures $278M Deal to Aid F/A 18 Aircraft Program (revised)'],
#  ['BA',
#   'Sep-01-22',
#   '11:35AM',
#   'UPDATE 1-Eye on Iran, Israel to buy four Boeing air force tankers for $927 mln'],
#  ['BA',
#   'Sep-01-22',
#   '11:15AM',
#   'Boeing banks billions for next batch of tankers'],
#  ['BA',
#   'Sep-01-22',
#   '11:07AM',
#   'Boeing (BA) Wins $2.2B Deal to Build KC-46 Tanker Aircraft'],
#  ['BA',
#   'Sep-01-22',
#   '10:20AM',
#   'Eye on Iran, Israel to buy four Boeing air force tankers for $927 million'],
#  ['BA',
#   'Sep-01-22',
#   '09:55AM',
#   "Virgin Atlantic, Corendon Dutch Airlines and Albawings Adopt Boeing's Digital Sustainability Solutions"],
#  ['BA',
#   'Sep-01-22',
#   '03:47AM',
#   'UPDATE 1-Boeing expects MAX 7 to be certified before MAX 10 - executive'],
#  ['BA',
#   'Sep-01-22',
#   '03:29AM',
#   'Boeing expects MAX 7 to be certified before MAX 10 - executive'],
#  ['BA',
#   'Sep-01-22',
#   '03:04AM',
#   'Boeing expects MAX 7 to be certified before MAX 10 - executive'],
#  ['BA',
#   'Sep-01-22',
#   '02:31AM',
#   'UPDATE 2-Boeing expects more orders from India as airlines boost capacity'],
#  ['BA',
#   'Sep-01-22',
#   '02:14AM',
#   'Boeing expects more orders from India as airlines boost capacity'],
#  ['BA',
#   'Aug-31-22',
#   '05:59PM',
#   'US Gets Warrant to Seize Boeing 737 Owned by Russias Lukoil'],
#  ['BA',
#   'Aug-31-22',
#   '05:57PM',
#   "UPDATE 1-NASA orders five more astronaut missions from Musk's SpaceX in $1.4 bln deal"],
#  ['BA',
#   'Aug-31-22',
#   '01:04PM',
#   'Boeing Stock Today: Why This Put Ratio Spread Could Net $1,000'],
#  ['BA',
#   'Aug-31-22',
#   '01:03PM',
#   "UPDATE 1-India's SpiceJet CFO resigns as losses widen"],
#  ['BA',
#   'Aug-31-22',
#   '09:00AM',
#   'The Boeing Company (BA) Is a Trending Stock: Facts to Know Before Betting on It'],
#  ['BA',
#   'Aug-30-22',
#   '08:21PM',
#   'NASA to Try Artemis I Moon Launch Again on Saturday'],
#  ['BA',
#   'Aug-30-22',
#   '08:09PM',
#   'U.S. Army Grounds Entire Fleet of Chinook Helicopters'],
#  ['BA',
#   'Aug-30-22',
#   '07:18PM',
#   'U.S. Army grounds Boeing-made Chinook helicopters fleet'],
#  ['BA',
#   'Aug-30-22',
#   '07:14PM',
#   'U.S. Army grounds Boeing-made Chinook helicopters fleet'],
#  ['BA',
#   'Aug-30-22',
#   '05:33PM',
#   'Boeing, Honeywell stocks drop after Army grounds Chinook helicopters'],
#  ['BA',
#   'Aug-30-22',
#   '03:21PM',
#   'Boeing, Spirit AeroSystems Inc. slide on customers MAX 10 expectation'],
#  ['BA',
#   'Aug-30-22',
#   '01:09PM',
#   'OLeary expects Ryanair to lure passengers from more expensive rivals'],
#  ['BA',
#   'Aug-30-22',
#   '12:22PM',
#   'UPDATE 2-Boeing customer Ryanair says MAX 10 will not be certified by year-end'],
#  ['BA',
#   'Aug-30-22',
#   '11:10AM',
#   'Boeing customer Ryanair says MAX 10 will not be certified by year-end'],
#  ['BA',
#   'Aug-30-22',
#   '10:44AM',
#   "Boeing customer Ryanair says MAX 10 won't be certified by year-end"],
#  ['BA', 'Aug-30-22', '09:33AM', 'Company News for Aug 30, 2022'],
#  ['BA',
#   'Aug-30-22',
#   '08:07AM',
#   'The Zacks Analyst Blog Highlights Raytheon Technologies, Boeing and L3Harris Technologies'],
#  ['BA',
#   'Aug-30-22',
#   '07:58AM',
#   "Taiwan's China Airlines Orders 16 Boeing 787s"],
#  ['BA',
#   'Aug-30-22',
#   '06:42AM',
#   'UPS adds to fleet with purchase of new airplanes from Boeing'],
#  ['BA',
#   'Aug-30-22',
#   '05:02AM',
#   "UPDATE 4-Taiwan's China Airlines to buy 16 Boeing 787s in $4.6 bln deal"],
#  ['BA',
#   'Aug-30-22',
#   '04:53AM',
#   "Taiwan's China Airlines to buy 16 Boeing 787s in $4.6 billion deal"],
# ...
#  ['KO',
#   'Aug-11-22',
#   '07:00AM',
#   'Exclusive: Seth Goldmans Eat the Change raises $14.5M to fill the Honest Tea void'],
#  ['KO',
#   'Aug-11-22',
#   '02:51AM',
#   'UPDATE 2-Coca-Cola HBC flags one-time $195 mln hit from Russian operations'],
#  ['KO',
#   'Aug-11-22',
#   '02:03AM',
#   'Coca-Cola HBC flags one-time $195 million hit from Russian operations'],
#  ['KO',
#   'Aug-11-22',
#   '02:00AM',
#   'Coca-Cola HBC flags one-time $195 mln hit from Russian operations'],
#  ['KO',
#   'Aug-10-22',
#   '02:38PM',
#   'Coca-Cola bottler to detail costs of exiting Russia'],
#  ['KO',
#   'Aug-10-22',
#   '02:35PM',
#   'Coca-Cola bottler to detail costs of exiting Russia'],
#  ['KO',
#   'Aug-10-22',
#   '10:20AM',
#   'Low-Risk Retirement Portfolio: Top 10 Stocks'],
#  ['KO',
#   'Aug-10-22',
#   '09:20AM',
#   'The Zacks Analyst Blog Highlights The Coca Cola, Altria Group and Procter & Gamble'],
#  ['KO',
#   'Aug-09-22',
#   '08:19PM',
#   'Coca-Cola is Finally Expanding on a Big Purchase'],
#  ['KO',
#   'Aug-09-22',
#   '12:16PM',
#   'Pockets of Strength in Consumer Staples Stocks: KO, MO, PG Earnings'],
#  ['KO',
#   'Aug-09-22',
#   '09:05AM',
#   '10 European Stocks to Sell Before Recession Starts'],
#  ['KO',
#   'Aug-08-22',
#   '04:52PM',
#   '10 Best Dividend Growth Stocks to Buy in August'],
#  ['KO',
#   'Aug-08-22',
#   '09:34AM',
#   'Donald Yacktmans Latest Portfolio: Top 10 Stock Picks'],
#  ['KO',
#   'Aug-08-22',
#   '09:17AM',
#   '10 Dividend Stocks to Buy According to Steve Cohens Point72 Asset Management'],
#  ['KO', 'Aug-08-22', '06:01AM', '3 Robinhood Stocks to Buy and Hold Forever'],
#  ['KO',
#   'Aug-05-22',
#   '04:51PM',
#   'Crypto companies spend upwards of $2.4 billion on sports marketing'],
#  ['KO', 'Aug-05-22', '09:10AM', '10 Safe Dividend Stocks to Buy Before 2023'],
#  ['KO',
#   'Aug-05-22',
#   '05:53AM',
#   'FTSE 100: WPP raises net sales outlook as advertising demand remains strong'],
#  ['KO',
#   'Aug-05-22',
#   '05:02AM',
#   'Advertising demand drives up sales for WPP but shares slide'],
#  ['KO',
#   'Aug-04-22',
#   '02:47PM',
#   'Coca-Cola distributor in Durham to shift HQ to new Chatham facility'],
#  ['KO',
#   'Aug-04-22',
#   '10:53AM',
#   'Paging Peter Lynch: 3 Dividend Stocks to Buy This August'],
#  ['KO',
#   'Aug-04-22',
#   '10:52AM',
#   '10 Dividend Stocks to Buy Now Before Recession Begins'],
#  ['KO', 'Aug-04-22', '08:00AM', 'Coca-Cola Stock Looks Unstoppable'],
#  ['KO', 'Aug-04-22', '07:58AM', 'Better Buy: Coca-Cola vs. PepsiCo'],
#  ['KO',
#   'Aug-04-22',
#   '06:29AM',
#   "Twinkie owner Hostess cites '20% inflation' in earnings beat"],
#  ['KO',
#   'Aug-03-22',
#   '10:06AM',
#   'Jim Cramers Recession Portfolio: Top 10 Stock Picks'],
#  ['KO',
#   'Aug-03-22',
#   '09:00AM',
#   'Is Most-Watched Stock CocaCola Company The (KO) Worth Betting on Now?'],
#  ['KO',
#   'Aug-03-22',
#   '05:06AM',
#   "Warren Buffett's 3 Favorite Sectors to Invest His Money"],
#  ['KO',
#   'Aug-02-22',
#   '11:02AM',
#   '10 Latest Earnings That Surprised Wall Street'],
#  ['KO', 'Aug-02-22', '10:17AM', '10 High Free Cash Flow Dividend Stocks'],
#  ['KO',
#   'Aug-02-22',
#   '03:49AM',
#   'Turkeys 79% Inflation Drives Company Debt Into Distressed Zone'],
#  ['KO', 'Aug-01-22', '10:15AM', 'Is Coca-Cola Stock a Buy After Q2 Earnings?'],
#  ['KO',
#   'Aug-01-22',
#   '09:12AM',
#   'Preferred Sector: 10 Beverage Stocks to Buy Now Despite Economic Headwinds'],
#  ['KO',
#   'Aug-01-22',
#   '05:30AM',
#   'Amgen Fights IRS Over $10.7 Billion Tax Bill'],
#  ['KO',
#   'Jul-31-22',
#   '08:46AM',
#   "Here's What Makes This Dow Jones Stock So Safe"],
#  ['KO', 'Jul-31-22', '08:20AM', 'Is Coca-Cola Stock a Buy?'],
#  ['KO', 'Jul-31-22', '07:30AM', '2 Dow Stocks to Buy More of in August'],
#  ['KO',
#   'Jul-31-22',
#   '05:00AM',
#   '3 Dividend Kings That Could Pay You for the Rest of Your Life'],
#  ['KO',
#   'Jul-29-22',
#   '08:38AM',
#   '7 Warren Buffet Stocks to Buy and Hold for the Next Decade'],
#  ['KO',
#   'Jul-29-22',
#   '05:06AM',
#   "80% of Warren Buffett's Portfolio Is Invested in These 7 Stocks"],
#  ['KO',
#   'Jul-28-22',
#   '07:00PM',
#   '7 Warren Buffett Stocks Trading at a Huge Discount Right Now'],
#  ['KO',
#   'Jul-28-22',
#   '05:10PM',
#   'Sprite discontinues green plastic bottles for environmental reasons'],
#  ['KO',
#   'Jul-28-22',
#   '03:24PM',
#   'These 10 Stocks are Gaining After Announcing Share Buybacks'],
#  ['KO',
#   'Jul-28-22',
#   '11:42AM',
#   'Sprite Goes Green by Ditching Its Green Bottle'],
#  ['KO',
#   'Jul-28-22',
#   '06:30AM',
#   'Bear Market Investing: 3 Reasons to Buy Stocks Now'],
#  ['KO',
#   'Jul-27-22',
#   '03:29PM',
#   "The U.S. isn't in a 'typical recession': Fmr Home Depot CEO"],
#  ['KO',
#   'Jul-27-22',
#   '10:18AM',
#   'Stocks: Tech leads gains, home builders fall, Sherwin-Williams sinks'],
#  ['KO', 'Jul-27-22', '09:18AM', 'Company News for Jul 27, 2022'],
#  ['KO',
#   'Jul-27-22',
#   '07:15AM',
#   'Got $1,000? 3 Warren Buffett Stocks to Buy Hand Over Fist'],
#  ['KO',
#   'Jul-27-22',
#   '05:50AM',
#   "Strategist: 'Soul-crushing' sell-offs 'may be delayed until late summer'"],
#  ['KO',
#   'Jul-26-22',
#   '10:38PM',
#   'Coca-Cola Posts Higher Quarterly Sales Despite Price Increases'],
#  ['KO',
#   'Jul-26-22',
#   '06:14PM',
#   'Dont Expect Big Consumer Brands to Lower Prices Soon'],
#  ['KO',
#   'Jul-26-22',
#   '04:55PM',
#   'US STOCKS-Indexes drop as Walmart profit warning spooks investors'],
#  ['KO',
#   'Jul-26-22',
#   '04:43PM',
#   'Treasury Moves to Ease Limits on Foreign Tax Credits After Companies Object'],
#  ['KO',
#   'Jul-26-22',
#   '04:00PM',
#   'US STOCKS-Indexes end sharply lower as Walmart profit warning spooks investors'],
#  ['DIS',
#   'Sep-01-22',
#   '06:24PM',
#   'Disney World Makes a Huge Change Walt Would Hate'],
#  ['DIS',
#   'Sep-01-22',
#   '01:00PM',
#   'Walt Disneys Grumman Gulfstream I Airplane Makes its West Coast Return for D23 Expo 2022'],
#  ['DIS',
#   'Sep-01-22',
#   '12:21PM',
#   "'It's a lifestyle': Disney explores new membership program beyond streaming platform"],
#  ['DIS',
#   'Sep-01-22',
#   '11:21AM',
#   'Disney Prime? Mouse House Mulling Membership Program Offering Perks, Discounts Across Products and Services'],
#  ['DIS',
#   'Sep-01-22',
#   '10:33AM',
#   'Disney is reportedly mulling an Amazon Primelike membership program'],
#  ['DIS',
#   'Sep-01-22',
#   '10:15AM',
#   '3 Dates for Disney Stock Investors to Circle in September'],
#  ['DIS',
#   'Sep-01-22',
#   '09:34AM',
#   'Disney explores Amazon Prime-like membership program'],
#  ['DIS',
#   'Sep-01-22',
#   '09:21AM',
#   'Disney plots Amazon Prime-style subscription perks'],
#  ['DIS',
#   'Sep-01-22',
#   '08:51AM',
#   '10 Best Stocks Under $50 According to Hedge Funds'],
#  ['DIS', 'Sep-01-22', '08:19AM', '2 Red Flags for Alphabet in 2022'],
#  ['DIS',
#   'Sep-01-22',
#   '07:44AM',
#   'Nvidia Ensnared in Geopolitical Spy Games With China Export Ban'],
#  ['DIS',
#   'Sep-01-22',
#   '07:30AM',
#   "Should You Buy the S&P 500's 3 Worst-Performing Stocks of 2022?"],
#  ['DIS', 'Sep-01-22', '07:07AM', '3 Disruptors I Love Right Now'],
#  ['DIS',
#   'Sep-01-22',
#   '06:57AM',
#   'Stock market today: 3 tickers trending on Yahoo Finance'],
#  ['DIS',
#   'Sep-01-22',
#   '05:18AM',
#   'Stocks Lower, Nvidia, Disney, Apple, Broadcom In Focus - Five Things To Know'],
#  ['DIS',
#   'Sep-01-22',
#   '04:00AM',
#   'Nvidia, Hormel Foods, Okta, Ciena Fall Premarket; Walt Disney Rises'],
#  ['DIS',
#   'Sep-01-22',
#   '12:19AM',
#   'Disney Looks to Offer Amazon Prime-Style Membership Program  WSJ'],
#  ['DIS',
#   'Aug-31-22',
#   '07:22PM',
#   'Top after-hours movers: Okta, Disney, Five Below and more'],
#  ['DIS',
#   'Aug-31-22',
#   '06:05PM',
#   'UPDATE 1-Disney mulls membership program to offer discounts and perks - WSJ'],
#  ['DIS',
#   'Aug-31-22',
#   '05:24PM',
#   'Disney mulls membership program to offer discounts and perks - WSJ'],
#  ['DIS',
#   'Aug-31-22',
#   '05:20PM',
#   'Disney mulling Amazon Prime-like membership program - WSJ'],
#  ['DIS', 'Aug-31-22', '05:04PM', 'Disney plans a membership service package'],
#  ['DIS',
#   'Aug-31-22',
#   '05:02PM',
#   'Disney Explores Membership Program Like Amazon Prime to Offer Discounts and Perks'],
#  ['DIS',
#   'Aug-31-22',
#   '04:51PM',
#   'Top Communications Stocks for September 2022'],
#  ['DIS',
#   'Aug-31-22',
#   '02:00PM',
#   'Lilly Singh (@lilly) and Raven-Symoné (@ravensymone) to Host Disneys Epic Entertainment Showcase: The Musical: The Extravaganza!, Presented by Disney Branded Television, Saturday, September 10, During the Ultimate Disney Fan Event D23 Expo 2022'],
#  ['DIS',
#   'Aug-31-22',
#   '01:00PM',
#   'The Walt Disney Company Executives to Participate in the 2022 Bank of America Securities Media, Communications & Entertainment Conference'],
#  ['DIS',
#   'Aug-31-22',
#   '12:51PM',
#   'Disney Reportedly Mulls Launching Amazon-Prime Rival Membership Program: DJ'],
#  ['DIS',
#   'Aug-31-22',
#   '10:57AM',
#   'Netflix (NFLX) Hires Two Top Snap Executives to Lead Ad Push'],
#  ['DIS',
#   'Aug-31-22',
#   '05:35AM',
#   'Disney Investors Should Watch Warner Bros. Discovery Closely'],
#  ['DIS',
#   'Aug-30-22',
#   '07:44PM',
#   'Disney World Bets Big on Star Wars, Controversial Attraction'],
#  ['DIS',
#   'Aug-30-22',
#   '07:40PM',
#   'Disney Theme Park Nears New Ride Inspired by Popular Character'],
#  ['DIS',
#   'Aug-30-22',
#   '11:13AM',
#   'Disney Cruise Line to drop Covid tests for vaccinated passengers soon'],
#  ['DIS',
#   'Aug-30-22',
#   '10:54AM',
#   "The Extra Costs of Netflix's Ad-Supported Tier"],
#  ['DIS',
#   'Aug-30-22',
#   '09:02AM',
#   '6 Restaurant Stocks to Watch Amid Tightening Spending'],
#  ['DIS',
#   'Aug-29-22',
#   '04:52PM',
#   'Las Vegas Has Some Good News for Its Visitors'],
#  ['DIS',
#   'Aug-29-22',
#   '10:59AM',
#   '4 Growth Stocks to Invest $100 in Right Now'],
#  ['DIS',
#   'Aug-29-22',
#   '09:04AM',
#   '10 Stocks At Risk From Slowing Chinese Economy'],
#  ['DIS',
#   'Aug-29-22',
#   '05:30AM',
#   'Some Companies Havent Paid a Dividend Since 2020. They Might Bring It Back as a Slowdown Looms'],
#  ['DIS',
#   'Aug-28-22',
#   '09:53AM',
#   'This Indicator Can Turn Even the Most Bearish Investors Into Netflix Bulls'],
#  ['DIS',
#   'Aug-28-22',
#   '08:30AM',
#   "Here's What to Watch For at Disney's D23 Convention"],
#  ['DIS', 'Aug-28-22', '08:00AM', 'Universal Studios Closer to Huge Addition'],
#  ['DIS', 'Aug-28-22', '08:00AM', 'Is Disney Stock a Buy?'],
#  ['DIS', 'Aug-28-22', '07:00AM', '3 Tech Stocks Down 50% or More to Buy Now'],
#  ['DIS',
#   'Aug-27-22',
#   '06:45PM',
#   'Disney Gets Deal to Broadcast Cricket Events in India'],
#  ['DIS',
#   'Aug-27-22',
#   '03:16PM',
#   'Universal Studios Has Something Special Planned For Halloween'],
#  ['DIS',
#   'Aug-27-22',
#   '11:37AM',
#   'Looking for Tech Stocks? These 3 Are Great Buys'],
#  ['DIS',
#   'Aug-27-22',
#   '10:46AM',
#   'Cricket-Disney Star to broadcast ICC events in India to end of 2027'],
#  ['DIS',
#   'Aug-27-22',
#   '10:45AM',
#   "This Beaten-Down Growth Stock Just Doesn't Have the Disney Magic"],
#  ['DIS', 'Aug-27-22', '07:00AM', '2 FAANG Stocks to Buy Now and 1 to Avoid'],
#  ['DIS', 'Aug-27-22', '06:57AM', 'Has Netflix Already Lost to Disney+?'],
#  ['DIS',
#   'Aug-27-22',
#   '12:00AM',
#   'Taking a Disney World Vacation? How to Budget for Hotels, Tickets and Food'],
#  ['DIS',
#   'Aug-27-22',
#   '12:00AM',
#   'Disneys New Pricing Magic: More Profit From Fewer Park Visitors'],
#  ['DIS',
#   'Aug-26-22',
#   '07:40PM',
#   'Netflix mulls $7-$9 per month for its ad-supported subscription - Bloomberg News'],
#  ['DIS', 'Aug-26-22', '04:28PM', 'Disney World Adds an Exciting New Event'],
#  ['DIS',
#   'Aug-26-22',
#   '12:50PM',
#   'NBC Considers Cutting Back Programming Hours in Prime Time'],
#  ['DIS',
#   'Aug-26-22',
#   '11:55AM',
#   'Is Disney+ Firing the Wrong Way in a Pricing War?'],
#  ['DIS',
#   'Aug-26-22',
#   '10:37AM',
#   'Could This Beaten-Down Stock Be Working on a Comeback?'],
#  ['DIS',
#   'Aug-26-22',
#   '09:00AM',
#   'The Walt Disney Company (DIS) is Attracting Investor Attention: Here is What You Should Know'],
#  ['DIS',
#   'Aug-26-22',
#   '08:30AM',
#   "Is Disney World's Popularity Starting to Fade?"],
#  ['DIS',
#   'Aug-26-22',
#   '05:26AM',
#   "Warner Bros. Discovery Is Taking a Page From Disney's Playbook. What Investors Should Watch."],
#  ['DIS',
#   'Aug-25-22',
#   '07:59PM',
#   'Disney Bringing Back a (Cult) Classic Movie'],
#  ['DIS',
#   'Aug-25-22',
#   '02:28PM',
#   'Disney Gives First Look Into Major New Epcot Attraction'],
#  ['DIS',
#   'Aug-25-22',
#   '01:00PM',
#   'Cant-Miss Panels and Presentations Announced for D23 Expo [LIVE]'],
#  ['DIS', 'Aug-25-22', '09:30AM', '2 Stocks to Hold for the Next 20 Years'],
#  ['DIS',
#   'Aug-25-22',
#   '08:28AM',
#   'The Walt Disney Company (NYSE:DIS) Shares Could Be 47% Below Their Intrinsic Value Estimate'],
#  ['DIS',
#   'Aug-24-22',
#   '01:41PM',
#   'Netflix (NFLX) Launches New Heads Up Game, Expands Portfolio'],
#  ['DIS',
#   'Aug-24-22',
#   '11:40AM',
#   'PSO or DIS: Which Is the Better Value Stock Right Now?'],
#  ['DIS',
#   'Aug-24-22',
#   '10:05AM',
#   'A Bad Year May Get Worse for Snapchat and Facebook Owners'],
#  ['DIS',
#   'Aug-24-22',
#   '08:00AM',
#   'The Los Angeles Angels Are for Sale After Big Spending Fails to Build a Winner'],
#  ['DIS',
#   'Aug-24-22',
#   '07:15AM',
#   'Disney Brings the Magic to This High-Growth Stock'],
#  ['DIS',
#   'Aug-24-22',
#   '05:51AM',
#   'Streaming Giants Disney, Netflix, and Hulu Just Put Another Nail in Cable TV'],
#  ['DIS', 'Aug-24-22', '05:05AM', "Is Google's Pain The Trade Desk's Gain?"],
#  ['DIS',
#   'Aug-23-22',
#   '06:54PM',
#   'These Beloved Disney Favorites Are Coming Back to Theaters'],
#  ['DIS',
#   'Aug-23-22',
#   '06:42PM',
#   "Disney+ and Hulu Membership Fees Are Going Up. Here's Why"],
#  ['DIS',
#   'Aug-23-22',
#   '05:00PM',
#   'A Disney Hotel Favorite Is Going Out of Business'],
#  ['DIS',
#   'Aug-23-22',
#   '04:21PM',
#   "Disney World Is Making a Change You're Going To Like"],
#  ['DIS',
#   'Aug-23-22',
#   '03:46PM',
#   '3 Companies That Enjoyed Remarkable Quarters'],
#  ['DIS',
#   'Aug-23-22',
#   '09:56AM',
#   "Missed the Big Move in Disney Stock? It's Not Too Late to Buy Now"],
#  ['DIS',
#   'Aug-23-22',
#   '08:15AM',
#   'For "Big Retail," It\'s All About Inventory'],
#  ['DIS',
#   'Aug-23-22',
#   '08:05AM',
#   'How Is The Trade Desk Able to Pull Off Its Stunning Business Growth?'],
#  ['DIS', 'Aug-23-22', '08:00AM', '2 Under-the-Radar Growth Stocks to Buy Now'],
#  ['DIS',
#   'Aug-23-22',
#   '05:35AM',
#   '2 Hypergrowth Stocks to Buy in 2022 and Beyond'],
#  ['DIS',
#   'Aug-22-22',
#   '05:08PM',
#   'Troubled Star Wars Video Game Remake\xa0Shifts to New Studio'],
#  ['DIS',
#   'Aug-22-22',
#   '04:58PM',
#   "Breaking: DeSantis, state agencies file to dismiss Disney's Reedy Creek lawsuit filed by Orlando-area residents"],
#  ['DIS',
#   'Aug-22-22',
#   '03:45PM',
#   'Did You Know You Can Buy a Piece of Formula 1?'],
#  ['DIS',
#   'Aug-22-22',
#   '03:21PM',
#   'Disney+ Members Get Valuable Theme Park Perks This Year'],
#  ['DIS',
#   'Aug-22-22',
#   '01:02PM',
#   "Disney's Stock Is on Fire After It Passes Netflix in Total Subscriptions"],
#  ['DIS',
#   'Aug-22-22',
#   '12:18PM',
#   "Big Details on Universal's New Epic Universe Theme Park Emerge"],
#  ['DIS',
#   'Aug-22-22',
#   '09:08AM',
#   'Netflix (NFLX) Might Plan to Make Kids Shows, Movies Ad-Free'],
#  ['DIS',
#   'Aug-22-22',
#   '09:00AM',
#   'DeSantis Taps Donors Griffin, Tudor Jones in $142 Million Haul'],
#  ['DIS',
#   'Aug-22-22',
#   '06:27AM',
#   'The Zacks Analyst Blog Highlights Netflix, Alphabet, Amazon.com, The Walt Disney Company and Warner Bros. Discovery'],
#  ['DIS',
#   'Aug-21-22',
#   '10:15AM',
#   'Warren Buffett Just Bought More of This Streaming Stock. Should You?'],
#  ['DIS',
#   'Aug-21-22',
#   '09:15AM',
#   "Alphabet's Genius Move Could Mean It's Coming for These Streaming Stocks"],
#  ['DIS', 'Aug-20-22', '12:30PM', 'Things Just Got Tougher for Peloton'],
#  ['DIS',
#   'Aug-20-22',
#   '10:15AM',
#   "Here's Why Warner Bros. Discovery Is a Stock to Buy"],
#  ['DIS',
#   'Aug-20-22',
#   '09:00AM',
#   "Six Flags gets treated like a 'day-care center for teenagers.' Its CEO is not happy"],
#  ['DIS',
#   'Aug-20-22',
#   '08:07AM',
#   'Cord Cutting Continues in Q2. Can Cable Stocks Survive?'],
#  ['DIS',
#   'Aug-20-22',
#   '07:00AM',
#   '3 Growth Stocks Up Between 27% and 30% In the Last Month: Should You Buy Now?'],
#  ['DIS',
#   'Aug-19-22',
#   '04:38PM',
#   'Activist investor calls on Disney to spin off ESPN'],
#  ['DIS',
#   'Aug-19-22',
#   '03:02PM',
#   '5 Stocks the Smart Money Bought Up in the Second Quarter'],
#  ...]

# %%
# !pip install bs4 --upgrade
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -luggy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
